# %% [markdown]
# # Scraping Data

# %%
#Helpers libraries

from urllib.request import urlopen  
import os.path as osp
import os
import logging
import zipfile
from glob import glob
logging.getLogger().setLevel('INFO')
from datetime import datetime,timedelta
import warnings
warnings.filterwarnings("ignore")

# %%
#Helpers fucntions

def download_file(url_str, path):
    url = urlopen(url_str)
    output = open(path, 'wb')       
    output.write(url.read())
    output.close()  
    
def extract_file(archive_path, target_dir):
    zip_file = zipfile.ZipFile(archive_path, 'r')
    zip_file.extractall(target_dir)
    zip_file.close()

# %%
BASE_URL = 'http://tennis-data.co.uk'
DATA_DIR = "/Users/seangolbad/tennislytics" #Change it depending on where you want to store the files
ATP_DIR = './{}/ATP'.format(DATA_DIR)
WTA_DIR = './{}/WTA'.format(DATA_DIR)

ATP_URLS = [BASE_URL + "/%i/%i.zip" % (i,i) for i in range(2000,2021)]
WTA_URLS = [BASE_URL + "/%iw/%i.zip" % (i,i) for i in range(2007,2021)]

os.makedirs(osp.join(ATP_DIR, 'archives'), exist_ok=True)
os.makedirs(osp.join(WTA_DIR, 'archives'), exist_ok=True)

for files, directory in ((ATP_URLS, ATP_DIR), (WTA_URLS, WTA_DIR)):
    for dl_path in files:
        logging.info("downloading & extracting file %s", dl_path)
        archive_path = osp.join(directory, 'archives', osp.basename(dl_path))
        download_file(dl_path, archive_path)
        extract_file(archive_path, directory)
    
ATP_FILES = sorted(glob("%s/*.xls*" % ATP_DIR))
WTA_FILES = sorted(glob("%s/*.xls*" % WTA_DIR))

df_atp = pd.concat([pd.read_excel(f) for f in ATP_FILES], ignore_index=True)
df_wta = pd.concat([pd.read_excel(f) for f in WTA_FILES], ignore_index=True)

logging.info("%i matches ATP in df_atp", df_atp.shape[0])
logging.info("%i matches WTA in df_wta", df_wta.shape[0])
# Out:
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2000/2000.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2001/2001.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2002/2002.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2003/2003.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2004/2004.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2005/2005.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2006/2006.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2007/2007.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2008/2008.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2009/2009.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2010/2010.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2011/2011.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2012/2012.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2013/2013.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2014/2014.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2015/2015.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2016/2016.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2017/2017.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2018/2018.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2019/2019.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2020/2020.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2007w/2007.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2008w/2008.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2009w/2009.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2010w/2010.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2011w/2011.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2012w/2012.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2013w/2013.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2014w/2014.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2015w/2015.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2016w/2016.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2017w/2017.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2018w/2018.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2019w/2019.zip
# INFO:root:downloading & extracting file http://tennis-data.co.uk/2020w/2020.zip
# INFO:root:55669 matches ATP in df_atp
# INFO:root:32870 matches WTA in df_wta

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.

# %%
df_atp.to_csv("df_atp.csv")

# %%
df_atp = pd.read_csv('df_atp.csv')

# %%
df_atp.T
# Out:
#                                          0      \
# Unnamed: 0                                   0
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                              Dosedel S.
# Loser                              Ljubicic I.
# WRank                                       63
# LRank                                       77
# W1                                         6.0
# L1                                         4.0
# W2                                         6.0
# L2                                         2.0
# W3                                         NaN
# L3                                         NaN
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      0.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          1      \
# Unnamed: 0                                   1
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                              Enqvist T.
# Loser                               Clement A.
# WRank                                        5
# LRank                                       56
# W1                                         6.0
# L1                                         3.0
# W2                                         6.0
# L2                                         3.0
# W3                                         NaN
# L3                                         NaN
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      0.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          2      \
# Unnamed: 0                                   2
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                               Escude N.
# Loser                            Baccanello P.
# WRank                                       40
# LRank                                      655
# W1                                         6.0
# L1                                         7.0
# W2                                         7.0
# L2                                         5.0
# W3                                         6.0
# L3                                         3.0
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      1.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          3      \
# Unnamed: 0                                   3
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                              Federer R.
# Loser                           Knippschild J.
# WRank                                       65
# LRank                                       87
# W1                                         6.0
# L1                                         1.0
# W2                                         6.0
# L2                                         4.0
# W3                                         NaN
# L3                                         NaN
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      0.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          4      \
# Unnamed: 0                                   4
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                             Fromberg R.
# Loser                            Woodbridge T.
# WRank                                       81
# LRank                                      198
# W1                                         7.0
# L1                                         6.0
# W2                                         5.0
# L2                                         7.0
# W3                                         6.0
# L3                                         4.0
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      1.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          5      \
# Unnamed: 0                                   5
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                            Gambill J.M.
# Loser                               Arthurs W.
# WRank                                       58
# LRank                                      105
# W1                                         3.0
# L1                                         6.0
# W2                                         7.0
# L2                                         6.0
# W3                                         6.0
# L3                                         4.0
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      1.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          6      \
# Unnamed: 0                                   6
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                             Grosjean S.
# Loser                                  Ilie A.
# WRank                                       26
# LRank                                       51
# W1                                         6.0
# L1                                         2.0
# W2                                         6.0
# L2                                         1.0
# W3                                         NaN
# L3                                         NaN
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      0.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          7      \
# Unnamed: 0                                   7
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                               Henman T.
# Loser                              Balcells J.
# WRank                                       11
# LRank                                      218
# W1                                         6.0
# L1                                         4.0
# W2                                         7.0
# L2                                         6.0
# W3                                         NaN
# L3                                         NaN
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      0.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          8      \
# Unnamed: 0                                   8
# ATP                                          1
# Location                              Adelaide
# Tournament  Australian Hardcourt Championships
# Date                                2000-01-03
# Series                           International
# Court                                  Outdoor
# Surface                                   Hard
# Round                                1st Round
# Best of                                      3
# Winner                               Hewitt L.
# Loser                             Woodforde M.
# WRank                                       24
# LRank                                      129
# W1                                         6.0
# L1                                         3.0
# W2                                         2.0
# L2                                         6.0
# W3                                         6.0
# L3                                         1.0
# W4                                         NaN
# L4                                         NaN
# W5                                         NaN
# L5                                         NaN
# Wsets                                      2.0
# Lsets                                      1.0
# Comment                              Completed
# CBW                                        NaN
# CBL                                        NaN
# GBW                                        NaN
# GBL                                        NaN
# IWW                                        NaN
# IWL                                        NaN
# SBW                                        NaN
# SBL                                        NaN
# B365W                                      NaN
# B365L                                      NaN
# B&WW                                       NaN
# B&WL                                       NaN
# EXW                                        NaN
# EXL                                        NaN
# PSW                                        NaN
# PSL                                        NaN
# WPts                                       NaN
# LPts                                       NaN
# UBW                                        NaN
# UBL                                        NaN
# LBW                                        NaN
# LBL                                        NaN
# SJW                                        NaN
# SJL                                        NaN
# MaxW                                       NaN
# MaxL                                       NaN
# AvgW                                       NaN
# AvgL                                       NaN
#
#                                          9      ...               55659  \
# Unnamed: 0                                   9  ...               55659
# ATP                                          1  ...                  19
# Location                              Adelaide  ...            New York
# Tournament  Australian Hardcourt Championships  ...             US Open
# Date                                2000-01-03  ...          2020-09-07
# Series                           International  ...          Grand Slam
# Court                                  Outdoor  ...             Outdoor
# Surface                                   Hard  ...                Hard
# Round                                1st Round  ...           4th Round
# Best of                                      3  ...                   5
# Winner                              Lisnard J.  ...            Thiem D.
# Loser                               Tebbutt M.  ...  Auger-Aliassime F.
# WRank                                      134  ...                 3.0
# LRank                                      351  ...                21.0
# W1                                         7.0  ...                 7.0
# L1                                         6.0  ...                 6.0
# W2                                         6.0  ...                 6.0
# L2                                         7.0  ...                 1.0
# W3                                         6.0  ...                 6.0
# L3                                         4.0  ...                 1.0
# W4                                         NaN  ...                 NaN
# L4                                         NaN  ...                 NaN
# W5                                         NaN  ...                 NaN
# L5                                         NaN  ...                 NaN
# Wsets                                      2.0  ...                 3.0
# Lsets                                      1.0  ...                 0.0
# Comment                              Completed  ...           Completed
# CBW                                        NaN  ...                 NaN
# CBL                                        NaN  ...                 NaN
# GBW                                        NaN  ...                 NaN
# GBL                                        NaN  ...                 NaN
# IWW                                        NaN  ...                 NaN
# IWL                                        NaN  ...                 NaN
# SBW                                        NaN  ...                 NaN
# SBL                                        NaN  ...                 NaN
# B365W                                      NaN  ...                 1.4
# B365L                                      NaN  ...                 3.0
# B&WW                                       NaN  ...                 NaN
# B&WL                                       NaN  ...                 NaN
# EXW                                        NaN  ...                 NaN
# EXL                                        NaN  ...                 NaN
# PSW                                        NaN  ...                1.41
# PSL                                        NaN  ...                3.24
# WPts                                       NaN  ...              7135.0
# LPts                                       NaN  ...              1806.0
# UBW                                        NaN  ...                 NaN
# UBL                                        NaN  ...                 NaN
# LBW                                        NaN  ...                 NaN
# LBL                                        NaN  ...                 NaN
# SJW                                        NaN  ...                 NaN
# SJL                                        NaN  ...                 NaN
# MaxW                                       NaN  ...                1.43
# MaxL                                       NaN  ...                3.32
# AvgW                                       NaN  ...                1.39
# AvgL                                       NaN  ...                3.05
#
#                     55660        55661          55662             55663  \
# Unnamed: 0          55660        55661          55662             55663
# ATP                    19           19             19                19
# Location         New York     New York       New York          New York
# Tournament        US Open      US Open        US Open           US Open
# Date           2020-09-08   2020-09-08     2020-09-08        2020-09-09
# Series         Grand Slam   Grand Slam     Grand Slam        Grand Slam
# Court             Outdoor      Outdoor        Outdoor           Outdoor
# Surface              Hard         Hard           Hard              Hard
# Round           4th Round    4th Round  Quarterfinals     Quarterfinals
# Best of                 5            5              5                 5
# Winner          Rublev A.  Medvedev D.      Zverev A.  Carreno Busta P.
# Loser       Berrettini M.    Tiafoe F.       Coric B.     Shapovalov D.
# WRank                14.0          5.0            7.0              27.0
# LRank                 8.0         82.0           32.0              17.0
# W1                    4.0          6.0            1.0               3.0
# L1                    6.0          4.0            6.0               6.0
# W2                    6.0          6.0            7.0               7.0
# L2                    3.0          1.0            6.0               6.0
# W3                    6.0          6.0            7.0               7.0
# L3                    3.0          0.0            6.0               6.0
# W4                    6.0          NaN            6.0               0.0
# L4                    3.0          NaN            3.0               6.0
# W5                    NaN          NaN            NaN               6.0
# L5                    NaN          NaN            NaN               3.0
# Wsets                 3.0          3.0            3.0               3.0
# Lsets                 1.0          0.0            1.0               2.0
# Comment         Completed    Completed      Completed         Completed
# CBW                   NaN          NaN            NaN               NaN
# CBL                   NaN          NaN            NaN               NaN
# GBW                   NaN          NaN            NaN               NaN
# GBL                   NaN          NaN            NaN               NaN
# IWW                   NaN          NaN            NaN               NaN
# IWL                   NaN          NaN            NaN               NaN
# SBW                   NaN          NaN            NaN               NaN
# SBL                   NaN          NaN            NaN               NaN
# B365W                 2.0         1.12           1.36               2.2
# B365L                 1.8          6.0            3.2              1.66
# B&WW                  NaN          NaN            NaN               NaN
# B&WL                  NaN          NaN            NaN               NaN
# EXW                   NaN          NaN            NaN               NaN
# EXL                   NaN          NaN            NaN               NaN
# PSW                   2.0         1.11           1.37              2.31
# PSL                  1.93         8.64           3.45               1.7
# WPts               2234.0       5890.0         3630.0            1500.0
# LPts               2940.0        700.0         1355.0            2075.0
# UBW                   NaN          NaN            NaN               NaN
# UBL                   NaN          NaN            NaN               NaN
# LBW                   NaN          NaN            NaN               NaN
# LBL                   NaN          NaN            NaN               NaN
# SJW                   NaN          NaN            NaN               NaN
# SJL                   NaN          NaN            NaN               NaN
# MaxW                  2.1         1.14           1.44              2.31
# MaxL                 1.93         8.64           3.58              1.73
# AvgW                 1.99          1.1           1.35              2.23
# AvgL                 1.83         7.11           3.22              1.67
#
#                     55664          55665             55666        55667  \
# Unnamed: 0          55664          55665             55666        55667
# ATP                    19             19                19           19
# Location         New York       New York          New York     New York
# Tournament        US Open        US Open           US Open      US Open
# Date           2020-09-09     2020-09-10        2020-09-11   2020-09-12
# Series         Grand Slam     Grand Slam        Grand Slam   Grand Slam
# Court             Outdoor        Outdoor           Outdoor      Outdoor
# Surface              Hard           Hard              Hard         Hard
# Round       Quarterfinals  Quarterfinals        Semifinals   Semifinals
# Best of                 5              5                 5            5
# Winner        Medvedev D.       Thiem D.         Zverev A.     Thiem D.
# Loser           Rublev A.   De Minaur A.  Carreno Busta P.  Medvedev D.
# WRank                 5.0            3.0               7.0          3.0
# LRank                14.0           28.0              27.0          5.0
# W1                    7.0            6.0               3.0          6.0
# L1                    6.0            1.0               6.0          2.0
# W2                    6.0            6.0               2.0          7.0
# L2                    3.0            2.0               6.0          6.0
# W3                    7.0            6.0               6.0          7.0
# L3                    6.0            4.0               3.0          6.0
# W4                    NaN            NaN               6.0          NaN
# L4                    NaN            NaN               4.0          NaN
# W5                    NaN            NaN               6.0          NaN
# L5                    NaN            NaN               3.0          NaN
# Wsets                 3.0            3.0               3.0          3.0
# Lsets                 0.0            0.0               2.0          0.0
# Comment         Completed      Completed         Completed    Completed
# CBW                   NaN            NaN               NaN          NaN
# CBL                   NaN            NaN               NaN          NaN
# GBW                   NaN            NaN               NaN          NaN
# GBL                   NaN            NaN               NaN          NaN
# IWW                   NaN            NaN               NaN          NaN
# IWL                   NaN            NaN               NaN          NaN
# SBW                   NaN            NaN               NaN          NaN
# SBL                   NaN            NaN               NaN          NaN
# B365W                1.25           1.16              1.36          2.0
# B365L                 4.0            5.0               3.2          1.8
# B&WW                  NaN            NaN               NaN          NaN
# B&WL                  NaN            NaN               NaN          NaN
# EXW                   NaN            NaN               NaN          NaN
# EXL                   NaN            NaN               NaN          NaN
# PSW                  1.28           1.22              1.37         2.04
# PSL                  4.14            5.0              3.43         1.88
# WPts               5890.0         7135.0            3630.0       7135.0
# LPts               2234.0         1485.0            1500.0       5890.0
# UBW                   NaN            NaN               NaN          NaN
# UBL                   NaN            NaN               NaN          NaN
# LBW                   NaN            NaN               NaN          NaN
# LBL                   NaN            NaN               NaN          NaN
# SJW                   NaN            NaN               NaN          NaN
# SJL                   NaN            NaN               NaN          NaN
# MaxW                 1.33           1.22              1.39         2.04
# MaxL                 4.44           5.54               3.5         1.95
# AvgW                 1.25           1.18              1.35         1.98
# AvgL                 3.98           5.04              3.28         1.86
#
#                  55668
# Unnamed: 0       55668
# ATP                 19
# Location      New York
# Tournament     US Open
# Date        2020-09-13
# Series      Grand Slam
# Court          Outdoor
# Surface           Hard
# Round        The Final
# Best of              5
# Winner        Thiem D.
# Loser        Zverev A.
# WRank              3.0
# LRank              7.0
# W1                 2.0
# L1                 6.0
# W2                 4.0
# L2                 6.0
# W3                 6.0
# L3                 4.0
# W4                 6.0
# L4                 3.0
# W5                 7.0
# L5                 6.0
# Wsets              3.0
# Lsets              2.0
# Comment      Completed
# CBW                NaN
# CBL                NaN
# GBW                NaN
# GBL                NaN
# IWW                NaN
# IWL                NaN
# SBW                NaN
# SBL                NaN
# B365W             1.25
# B365L              4.0
# B&WW               NaN
# B&WL               NaN
# EXW                NaN
# EXL                NaN
# PSW                1.3
# PSL                4.0
# WPts            7135.0
# LPts            3630.0
# UBW                NaN
# UBL                NaN
# LBW                NaN
# LBL                NaN
# SJW                NaN
# SJL                NaN
# MaxW              1.31
# MaxL              4.33
# AvgW              1.27
# AvgL              3.84
#
# [55 rows x 55669 columns]

# %%
df_atp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55669 entries, 0 to 55668
# Data columns (total 55 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  55669 non-null  int64
#  1   ATP         55669 non-null  int64
#  2   Location    55669 non-null  object
#  3   Tournament  55669 non-null  object
#  4   Date        55669 non-null  object
#  5   Series      55669 non-null  object
#  6   Court       55669 non-null  object
#  7   Surface     55669 non-null  object
#  8   Round       55669 non-null  object
#  9   Best of     55669 non-null  int64
#  10  Winner      55669 non-null  object
#  11  Loser       55669 non-null  object
#  12  WRank       55649 non-null  object
#  13  LRank       55573 non-null  object
#  14  W1          55381 non-null  float64
#  15  L1          55383 non-null  float64
#  16  W2          55669 non-null  object
#  17  L2          54855 non-null  object
#  18  W3          25859 non-null  object
#  19  L3          25858 non-null  object
#  20  W4          5121 non-null   float64
#  21  L4          5121 non-null   float64
#  22  W5          1941 non-null   float64
#  23  L5          1941 non-null   float64
#  24  Wsets       55420 non-null  float64
#  25  Lsets       55419 non-null  object
#  26  Comment     55669 non-null  object
#  27  CBW         17506 non-null  float64
#  28  CBL         17506 non-null  float64
#  29  GBW         5055 non-null   float64
#  30  GBL         5055 non-null   float64
#  31  IWW         13358 non-null  float64
#  32  IWL         13358 non-null  float64
#  33  SBW         5424 non-null   float64
#  34  SBL         5424 non-null   float64
#  35  B365W       46997 non-null  float64
#  36  B365L       47020 non-null  float64
#  37  B&WW        1097 non-null   float64
#  38  B&WL        1097 non-null   float64
#  39  EXW         39411 non-null  object
#  40  EXL         39416 non-null  float64
#  41  PSW         40693 non-null  float64
#  42  PSL         40693 non-null  float64
#  43  WPts        39461 non-null  float64
#  44  LPts        39388 non-null  float64
#  45  UBW         10671 non-null  float64
#  46  UBL         10671 non-null  float64
#  47  LBW         28131 non-null  float64
#  48  LBL         28142 non-null  float64
#  49  SJW         15572 non-null  float64
#  50  SJL         15579 non-null  float64
#  51  MaxW        26115 non-null  float64
#  52  MaxL        26115 non-null  float64
#  53  AvgW        26115 non-null  float64
#  54  AvgL        26115 non-null  float64
# dtypes: float64(34), int64(3), object(18)
# memory usage: 23.4+ MB

# %%
df_atp.describe(include='object').T
# Out:
#               count  unique              top     freq
# Location      55669     117            Paris     3480
# Tournament    55669     224  Australian Open     2667
# Date          55669    5005       2001-01-15      127
# Series        55669       8           ATP250    12837
# Court         55669       2          Outdoor    45748
# Surface       55669       4             Hard    29841
# Round         55669       8        1st Round    25748
# Winner        55669     989       Federer R.     1177
# Loser         55669    1540         Lopez F.      436
# WRank       55649.0  1232.0              1.0    934.0
# LRank       55573.0  1885.0             46.0    358.0
# W2          55669.0    25.0              6.0  25372.0
# L2          54855.0    25.0              6.0   9603.0
# W3            25859      25              6.0     7830
# L3          25858.0    25.0              4.0   4082.0
# Lsets       55419.0    10.0              0.0  24281.0
# Comment       55669       6        Completed    53632
# EXW         39411.0   542.0             1.35    771.0

# %% [markdown]
# ## Pandas Profiling

# %%
# installing package
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      |████████████████████████████████| 324 kB 2.5 MB/s eta 0:00:01
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.3.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 26.4 MB/s eta 0:00:01
# Collecting statsmodels<1,>=0.13.2
#   Downloading statsmodels-0.14.0-cp39-cp39-macosx_10_9_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 21.8 MB/s eta 0:00:01     |██████▏                         | 1.9 MB 21.8 MB/s eta 0:00:01
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.3.4)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
# Collecting pydantic<2,>=1.8.1
#   Downloading pydantic-1.10.9-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 52.7 MB/s eta 0:00:01
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      |████████████████████████████████| 296 kB 50.0 MB/s eta 0:00:01
# Collecting dacite>=1.8
#   Downloading dacite-1.8.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.30.0)
# Collecting typeguard<3,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: matplotlib<4,>=3.2 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (3.4.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 86.6 MB/s eta 0:00:01
# Collecting wordcloud>=1.9.1
#   Downloading wordcloud-1.9.2-cp39-cp39-macosx_10_9_x86_64.whl (161 kB)
#      |████████████████████████████████| 161 kB 35.8 MB/s eta 0:00:01
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-macosx_10_13_x86_64.whl (652 kB)
#      |████████████████████████████████| 652 kB 37.8 MB/s eta 0:00:01
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (2.11.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (4.62.3)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.20.3)
# Requirement already satisfied: scipy<1.11,>=1.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from ydata-profiling->pandas-profiling) (1.7.1)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.1.1)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.9/site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (8.4.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.6.3)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 21.6 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (1.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (3.0.4)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib<4,>=3.2->ydata-profiling->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.9/site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata-profiling->pandas-profiling) (2021.3)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/lib/python3.9/site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.6.3-py3-none-any.whl (31 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.7)
# Collecting packaging>=21.3
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 10.8 MB/s eta 0:00:01
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/lib/python3.9/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27098 sha256=d58a6164efe7d3b1c5d9684b27125f6b3b3d6d4f4bfd0b56db75e34beea5c917
#   Stored in directory: /Users/seangolbad/Library/Caches/pip/wheels/1d/05/04/c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: tangled-up-in-unicode, multimethod, visions, typing-extensions, packaging, imagehash, wordcloud, typeguard, statsmodels, pydantic, phik, htmlmin, dacite, ydata-profiling, pandas-profiling
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Uninstalling packaging-21.0:
#       Successfully uninstalled packaging-21.0
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Uninstalling statsmodels-0.12.2:
#       Successfully uninstalled statsmodels-0.12.2
# Successfully installed dacite-1.8.1 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 packaging-23.1 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.9 statsmodels-0.14.0 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 typing-extensions-4.6.3 visions-0.7.5 wordcloud-1.9.2 ydata-profiling-4.3.0

# %%
#importing library

from pandas_profiling import ProfileReport
#defining the library
profile = ProfileReport(df)
# exporting your report as a html file
profile.to_file(output_file='report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
